# %%
import pandas as pd
import requests
import json
from sqlalchemy import create_engine
from tmdb_config import API_KEY
from pprint import pprint

# Import csv file
#movie_data = pd.read_csv("bestPic2018Data.csv")
#movie_data = pd.read_csv("bestPic2016-2017Data.csv")
movie_data = pd.read_csv("bestactress_20161718.csv")

#movie_data

# %%
#list of movie titles to query
movies = movie_data['movieName']
#movies

# %%
# Build the endpoint URL
url = 'https://api.themoviedb.org/3/search/movie?'
api_key = f'api_key={API_KEY}&query='

# set up lists to hold response data:
movie_id = []
genres = []
original_language = []
original_title = []
overview = []
popularity = []
title = []
vote_average = []
vote_count = []

# junk list
junk_list = []

# loop through movie titles, make requests and parse
for movie in movies :
    response = requests.get(url + api_key + movie).json()
    try:
        movie_id.append(response['results'][0]['id'])
        genres.append(response['results'][0]['genre_ids'])
        original_language.append(response['results'][0]['original_language'])
        original_title.append(response['results'][0]['original_title'])
        overview.append(response['results'][0]['overview'])
        popularity.append(response['results'][0]['popularity'])
        title.append(response['results'][0]['title'])
        vote_average.append(response['results'][0]['vote_average'])
        vote_count.append(response['results'][0]['vote_count'])

    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#print(junk_list)
import ast
from pandas.io.json import json_normalize 
url = 'https://api.themoviedb.org/3/genre/movie/list?'
api_key = f'api_key={API_KEY}&language=en-US'
#genres_mapping = []
response = requests.get(url + api_key  ).json()
data = response
df = json_normalize(data, 'genres')
#data.set_index('Locality', inplace=True)
df = df.set_index('id')
#print (df)
# 
# json_str = json.dumps(data)
# data = json.loads(json_str)
# print((data))
print(genres)
genres_cleaned = []
for genre in genres:
    #print(genre)
    genre_name = []
    for i in genre:
        genre_new = {}
        genre_new["id"] = i
        #genre_name.append()
        genre_new["name"] = df.loc[i,'name']
        genre_name.append(genre_new)
    #genre_new = dict(zip("id":genre, "name":genre_name))
    genres_cleaned.append(genre_name)
# print(genres_cleaned)
#(genres_cleaned).replace("'", '"')
print(genres_cleaned)
#genres_data = json.dumps(ast.literal_eval(genres_cleaned))
# genres_clean = json.dumps(genres_cleaned)
# print(genres_clean)
    #[{"id": 28, "name": "Action"}, {"id": 12, "nam.
# Out:
# [[18], [18], [18], [18, 36], [18], [18], [18], [18, 10749], [35, 18], [18, 14, 10749], [18, 36, 35], [18], [18, 10749, 80], [18, 36, 35]]
# [[{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}], [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10749, 'name': 'Romance'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 35, 'name': 'Comedy'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'id': 80, 'name': 'Crime'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 35, 'name': 'Comedy'}]]

# %%
# Making a pass to get more detailed data, have to use ids

# Build the endpoint URL
url = 'https://api.themoviedb.org/3/movie/'
api_key = f'?api_key={API_KEY}&query='

budget = []
production_companies = []
production_countries = []
status = []
tagline = []
release_date = []
revenue = []
runtime = []
spoken_languages = []

# loop through movie ids, make requests and parse
for movie in movie_id :
    response = requests.get(url + str(movie) + api_key).json()
    try:
        budget.append(response['budget'])
        production_companies.append(response['production_companies'])
        production_countries.append(response['production_countries'])
        status.append(response['status'])
        tagline.append(response['tagline'])
        release_date.append(response['release_date'])        
        revenue.append(response['revenue'])
        runtime.append(response['runtime'])
        spoken_languages.append(response['spoken_languages'])
    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#budget

# %%
# Making a pass to get cast data, have to use ids

# Build the endpoint URL
url = 'https://api.themoviedb.org/3/movie/'
api_key = f'/credits?api_key={API_KEY}&query='

cast = []
crew = []

# loop through movie ids, make requests and parse
for movie in movie_id :
    response = requests.get(url + str(movie) + api_key).json()
    try:
        cast.append(response['cast'])
        crew.append(response['crew'])
    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#cast

# %%
# Making a pass to get keywords data, have to use ids

# Build the endpoint URL
url = 'https://api.themoviedb.org/3/movie/'
api_key = f'/keywords?api_key={API_KEY}&query='

keywords = []

# loop through movie ids, make requests and parse
for movie in movie_id :
    response = requests.get(url + str(movie) + api_key).json()
    try:
        keywords.append(response['keywords'])
    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#keywords

# %%
# This Block for sorting through errors
print(genres_cleaned)
#print("Length of Ranks Series: " , len(ranks))
#for junk in junk_list:
#    print(junk)
#    i=movies[movies==junk]
#    print(i.index, i.index[0])
#    ranks = ranks.drop(i.index[0])
#print("Length of Ranks Series: " , len(ranks))
# Out:
# [[{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}], [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10749, 'name': 'Romance'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 35, 'name': 'Comedy'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'id': 80, 'name': 'Crime'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 35, 'name': 'Comedy'}]]

# %%
# save data to pandas dataframe
movies_df = pd.DataFrame({
    'title' : title,
    'cast' : cast,
    'crew' : crew,
    'budget' : budget,
    'genres_new' : genres_cleaned,
    'movie_id' : movie_id,
    'keywords' : keywords,
    'original_language' : original_language,
    'original_title' : original_title,
    'overview' : overview,
    'popularity' : popularity,
    'production_companies' : production_companies,
    'production_countries' : production_countries,
    'release_date' : release_date,
    'revenue' : revenue,
    'runtime' : runtime,
    'spoken_languages' : spoken_languages,
    'status' : status,
    'tagline' : tagline,
    'vote_average' : vote_average,
    'vote_count' : vote_count
})
movies_df['cast']['name'].values[1]
# movies_df.genres
# Out:
# [{'cast_id': 7,
#   'character': 'Chiron "Black" Harris',
#   'credit_id': '57acaebf9251417409000461',
#   'gender': 2,
#   'id': 1650301,
#   'name': 'Trevante Rhodes',
#   'order': 0,
#   'profile_path': '/w5mqvAJ4FQAO5iZbO5Q5vv0MJ5s.jpg'},
#  {'cast_id': 3,
#   'character': 'Kevin Jones',
#   'credit_id': '573b4b4392514113ac00002d',
#   'gender': 2,
#   'id': 459980,
#   'name': 'André Holland',
#   'order': 1,
#   'profile_path': '/nq6qk6P5idimcSJ0bpFqLQrb0Li.jpg'},
#  {'cast_id': 6,
#   'character': 'Teresa',
#   'credit_id': '57acaea8c3a3681daa00294c',
#   'gender': 1,
#   'id': 1005852,
#   'name': 'Janelle Monáe',
#   'order': 2,
#   'profile_path': '/xavjGiGltQEDWqNdbe0zd1lO0UR.jpg'},
#  {'cast_id': 8,
#   'character': 'Teen Chiron Harris',
#   'credit_id': '57acaed2c3a3681ee300058a',
#   'gender': 2,
#   'id': 1152019,
#   'name': 'Ashton Sanders',
#   'order': 3,
#   'profile_path': '/eONLhaBvc3IyhWsfwdIdbRnbK9M.jpg'},
#  {'cast_id': 9,
#   'character': 'Teen Kevin Jones',
#   'credit_id': '57acaeefc3a3681daa00296c',
#   'gender': 2,
#   'id': 1664716,
#   'name': 'Jharrel Jerome',
#   'order': 4,
#   'profile_path': '/b8jynZLTUce2BOrVaD3S6CToKL8.jpg'},
#  {'cast_id': 22,
#   'character': 'Child Chiron "Little" Harris',
#   'credit_id': '57f34064c3a368334500636d',
#   'gender': 2,
#   'id': 1688889,
#   'name': 'Alex Hibbert',
#   'order': 5,
#   'profile_path': '/rWUu41SSz4bTiphToue2BrAlqZv.jpg'},
#  {'cast_id': 23,
#   'character': 'Child Kevin Jones',
#   'credit_id': '580e6f89c3a36859a40037f1',
#   'gender': 0,
#   'id': 1699116,
#   'name': 'Jaden Piner',
#   'order': 6,
#   'profile_path': '/9fNbkVJ7qdOiXsj9wYuWCsfJiIO.jpg'},
#  {'cast_id': 1,
#   'character': 'Paula',
#   'credit_id': '573b4b26c3a3684df7000031',
#   'gender': 1,
#   'id': 2038,
#   'name': 'Naomie Harris',
#   'order': 7,
#   'profile_path': '/41TVAcYqKKF7PGf3x7QfaLvkLSW.jpg'},
#  {'cast_id': 2,
#   'character': 'Juan',
#   'credit_id': '573b4b3192514113b6000038',
#   'gender': 2,
#   'id': 932967,
#   'name': 'Mahershala Ali',
#   'order': 8,
#   'profile_path': '/y9mf12rlZBlVJS6JYuCPpjTaLT6.jpg'},
#  {'cast_id': 24,
#   'character': 'Terrel',
#   'credit_id': '5826a2c1c3a368360f015420',
#   'gender': 2,
#   'id': 1707244,
#   'name': 'Patrick Decile',
#   'order': 9,
#   'profile_path': '/gXESjQ1MQAWuSjCw3K8KC7Bzdy9.jpg'},
#  {'cast_id': 10,
#   'character': 'Mr. Pierce',
#   'credit_id': '57acaf03c3a3681daa002974',
#   'gender': 2,
#   'id': 1664717,
#   'name': 'Edson Jean',
#   'order': 10,
#   'profile_path': '/ulrc5m8JejzNe5k5F5u9LHRpwXv.jpg'},
#  {'cast_id': 25,
#   'character': 'Terrence',
#   'credit_id': '5854565dc3a368258c02a1dc',
#   'gender': 2,
#   'id': 1723625,
#   'name': 'Shariff Earp',
#   'order': 11,
#   'profile_path': None},
#  {'cast_id': 26,
#   'character': 'Azu',
#   'credit_id': '5854566892514146c9022b11',
#   'gender': 2,
#   'id': 1723626,
#   'name': 'Duan Sanderson',
#   'order': 12,
#   'profile_path': None},
#  {'cast_id': 27,
#   'character': 'Gee',
#   'credit_id': '585456769251416fa1033b13',
#   'gender': 0,
#   'id': 1723627,
#   'name': 'Rudi Goblen',
#   'order': 13,
#   'profile_path': None},
#  {'cast_id': 28,
#   'character': 'Samantha',
#   'credit_id': '5854568792514175ad028423',
#   'gender': 0,
#   'id': 1723628,
#   'name': 'Herveline Moncion',
#   'order': 14,
#   'profile_path': None},
#  {'cast_id': 29,
#   'character': 'Pizzo',
#   'credit_id': '58545690925141724d009b12',
#   'gender': 0,
#   'id': 1723629,
#   'name': 'Fransley Hyppolite',
#   'order': 15,
#   'profile_path': None},
#  {'cast_id': 30,
#   'character': 'Antwon',
#   'credit_id': '585456a89251416fad033529',
#   'gender': 0,
#   'id': 1723630,
#   'name': 'Larry Anderson',
#   'order': 16,
#   'profile_path': None},
#  {'cast_id': 31,
#   'character': 'Principal Williams',
#   'credit_id': '585456b39251416f10035030',
#   'gender': 0,
#   'id': 1723631,
#   'name': 'Tanisha Cidel',
#   'order': 17,
#   'profile_path': None},
#  {'cast_id': 32,
#   'character': 'Travis',
#   'credit_id': '585456be9251416fa1033b54',
#   'gender': 0,
#   'id': 1723632,
#   'name': 'Stephon Bron',
#   'order': 18,
#   'profile_path': None},
#  {'cast_id': 33,
#   'character': 'Tip',
#   'credit_id': '585456c99251416fa1033b60',
#   'gender': 0,
#   'id': 1723633,
#   'name': 'Don Seward',
#   'order': 19,
#   'profile_path': None},
#  {'cast_id': 42,
#   'character': 'Gang Member',
#   'credit_id': '596e4f6c9251412aa600522e',
#   'gender': 0,
#   'id': 1853835,
#   'name': 'Justin Ebenhack',
#   'order': 20,
#   'profile_path': None}]

# %%
#movies_df.to_csv('2018_best_picture_tmdb.csv', index=False)
movies_df.to_csv('2016_2017_best_actresssupport_tmdb2.csv', index=False)
