# %%
from bs4 import BeautifulSoup
import requests

# Create lists to append to
#I did not collect rating as it returned an image and I did not collect Media as a movie's distribution only affects sales
title = []
year = []
rank = []
directors = []
countries = []

# URL of page to be scraped
url = 'http://www.films101.com/year10y.htm'
url2 = 'http://www.films101.com/year10y2.htm'
url3 = 'http://www.films101.com/year10y3.htm'

# Retrieve page with the requests module
response = requests.get(url)
response2 = requests.get(url2)
response3 = requests.get(url3)

# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')
soup2 = BeautifulSoup(response2.text, 'html.parser')
soup3 = BeautifulSoup(response3.text, 'html.parser')

# Examine the results, then determine element that contains sought info
#print(soup.prettify())

# %%
# results are returned as an iterable list
results = soup.find_all('tr') + soup2.find_all('tr') + soup3.find_all('tr') 
#results

# %%
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of movie
        t1 = result.find('td', class_="zt1").text
        title.append(t1)

        # Identify and return year of movie
        y1 = result.find('td', class_="zy1").text
        year.append(y1)
        
        # Identify and return rank of movie
        r1 = result.find('td', class_="zn4").text
        rank.append(r1)
        
        # Identify and return directors of movie
        d1 = result.find('td', class_="zd4").text
        directors.append(d1)
        
        # Identify and return country of movie
        c1 = result.find('td', class_="zc4").text
        countries.append(c1)
        
    except AttributeError as e:
        print(e)
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'

# %%
# Cleaning with Pandas
import pandas as pd

df = pd.DataFrame({
    'Title' : title,
    'Year' : year,
    'Rank' : rank,
    'Directors' : directors,
    'Countries' : countries,
})

df
# Out:
#                                              Title  Year Rank  \
# 0                              Avengers: Endgame    2019    1
# 1                                    The Mustang    2019    2
# 2                                      Apollo 11    2019    3
# 3                                             Us    2019    4
# 4       How to Train Your Dragon: The Hidden World  2019    5
# 5                                   Captain Marvel  2019    6
# 6                           Knock Down the House    2019    6
# 7                                        Shazam!    2019    6
# 8                                         Clemency  2019    7
# 9                                        Honeyland  2019    7
# 10                                One Child Nation  2019    7
# 11                                    The Souvenir  2019    7
# 12                                   Hail Satan?    2019    8
# 13               The Lego Movie 2: The Second Part  2019    9
# ...

# %%
df.to_csv('films101.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-5-060a66360e97> in <module>
# ----> 1 df.to_csv('films101.csv', index=False)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# C:\Anaconda\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# ...
