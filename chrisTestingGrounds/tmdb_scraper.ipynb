# %%
import pandas as pd
import requests
import json
from sqlalchemy import create_engine
from tmdb_config import API_KEY
from pprint import pprint

# Import csv file
movie_data = pd.read_csv("bestPic2018Data.csv")
#movie_data = pd.read_csv("bestPic2016-2017Data.csv")

#movie_data
# Out:
#     year  ceremony         award  winner  \
# 0   2016        89  Best Picture       1
# 1   2016        89  Best Picture       1
# 2   2016        89  Best Picture       1
# 3   2016        89  Best Picture       1
# 4   2016        89  Best Picture       1
# 5   2016        89  Best Picture       1
# 6   2016        89  Best Picture       1
# 7   2016        89  Best Picture       1
# 8   2016        89  Best Picture       1
# 9   2017        90  Best Picture       1
# 10  2017        90  Best Picture       1
# 11  2017        90  Best Picture       1
# 12  2017        90  Best Picture       1
# 13  2017        90  Best Picture       1
# 14  2017        90  Best Picture       1
# 15  2017        90  Best Picture       1
# 16  2017        90  Best Picture       1
# 17  2017        90  Best Picture       1
#
#                                     movieName  \
# 0                                     Arrival
# 1                                      Fences
# 2                               Hacksaw Ridge
# 3                          Hell or High Water
# 4                              Hidden Figures
# 5                                  La La Land
# 6                                        Lion
# 7                       Manchester by the Sea
# 8                                   Moonlight
# 9                        Call Me by Your Name
# 10                               Darkest Hour
# 11                                    Dunkirk
# 12                                    Get Out
# 13                                  Lady Bird
# 14                             Phantom Thread
# 15                                   The Post
# 16                         The Shape of Water
# 17  Three Billboards outside Ebbing, Missouri
#
#                                              filmInfo
# 0   Shawn Levy, Dan Levine, Aaron Ryder and David ...
# 1   Scott Rudin, Denzel Washington and Todd Black,...
# 2           Bill Mechanic and David Permut, Producers
# 3              Carla Hacken and Julie Yorn, Producers
# 4   Donna Gigliotti, Peter Chernin, Jenno Topping,...
# 5   Fred Berger, Jordan Horowitz and Marc Platt, P...
# 6   Emile Sherman, Iain Canning and Angie Fielder,...
# 7   Matt Damon, Kimberly Steward, Chris Moore, Lau...
# 8   Adele Romanski, Dede Gardner and Jeremy Kleine...
# 9   Peter Spears, Luca Guadagnino, Emilie Georges ...
# 10  Tim Bevan, Eric Fellner, Lisa Bruce, Anthony M...
# 11       Emma Thomas and Christopher Nolan, Producers
# 12  Sean McKittrick, Jason Blum, Edward H. Hamm Jr...
# 13  Scott Rudin, Eli Bush and Evelyn O'Neill, Prod...
# 14  JoAnne Sellar, Paul Thomas Anderson, Megan Ell...
# 15  Amy Pascal, Steven Spielberg and Kristie Macos...
# 16    Guillermo del Toro and J. Miles Dale, Producers
# 17  Graham Broadbent, Pete Czernin and Martin McDo...

# %%
#list of movie titles to query
movies = movie_data['movieName']
#movies

# %%
# Build the endpoint URL
url = 'https://api.themoviedb.org/3/search/movie?'
api_key = f'api_key={API_KEY}&query='

# set up lists to hold response data:
movie_id = []
genres = []
original_language = []
original_title = []
overview = []
popularity = []
title = []
vote_average = []
vote_count = []

# junk list
junk_list = []

# loop through movie titles, make requests and parse
for movie in movies :
    response = requests.get(url + api_key + movie).json()
    try:
        movie_id.append(response['results'][0]['id'])
        genres.append(response['results'][0]['genre_ids'])
        original_language.append(response['results'][0]['original_language'])
        original_title.append(response['results'][0]['original_title'])
        overview.append(response['results'][0]['overview'])
        popularity.append(response['results'][0]['popularity'])
        title.append(response['results'][0]['title'])
        vote_average.append(response['results'][0]['vote_average'])
        vote_count.append(response['results'][0]['vote_count'])

    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#print(junk_list)

# %%
# Making a pass to get more detailed data, have to use ids

# Build the endpoint URL
url = 'https://api.themoviedb.org/3/movie/'
api_key = f'?api_key={API_KEY}&query='

budget = []
production_companies = []
production_countries = []
status = []
tagline = []
release_date = []
revenue = []
runtime = []
spoken_languages = []

# loop through movie ids, make requests and parse
for movie in movie_id :
    response = requests.get(url + str(movie) + api_key).json()
    try:
        budget.append(response['budget'])
        production_companies.append(response['production_companies'])
        production_countries.append(response['production_countries'])
        status.append(response['status'])
        tagline.append(response['tagline'])
        release_date.append(response['release_date'])        
        revenue.append(response['revenue'])
        runtime.append(response['runtime'])
        spoken_languages.append(response['spoken_languages'])
    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#budget

# %%
# Making a pass to get cast data, have to use ids

# Build the endpoint URL
url = 'https://api.themoviedb.org/3/movie/'
api_key = f'/credits?api_key={API_KEY}&query='

cast = []
crew = []

# loop through movie ids, make requests and parse
for movie in movie_id :
    response = requests.get(url + str(movie) + api_key).json()
    try:
        cast.append(response['cast'])
        crew.append(response['crew'])
    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#cast

# %%
# Making a pass to get keywords data, have to use ids

# Build the endpoint URL
url = 'https://api.themoviedb.org/3/movie/'
api_key = f'/keywords?api_key={API_KEY}&query='

keywords = []

# loop through movie ids, make requests and parse
for movie in movie_id :
    response = requests.get(url + str(movie) + api_key).json()
    try:
        keywords.append(response['keywords'])
    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#keywords

# %%
# This Block for sorting through errors

#print("Length of Ranks Series: " , len(ranks))
#for junk in junk_list:
#    print(junk)
#    i=movies[movies==junk]
#    print(i.index, i.index[0])
#    ranks = ranks.drop(i.index[0])
#print("Length of Ranks Series: " , len(ranks))

# %%
# save data to pandas dataframe
movies_df = pd.DataFrame({
    'title' : title,
    'cast' : cast,
    'crew' : crew,
    'budget' : budget,
    'genres' : genres,
    'movie_id' : movie_id,
    'keywords' : keywords,
    'original_language' : original_language,
    'original_title' : original_title,
    'overview' : overview,
    'popularity' : popularity,
    'production_companies' : production_companies,
    'production_countries' : production_countries,
    'release_date' : release_date,
    'revenue' : revenue,
    'runtime' : runtime,
    'spoken_languages' : spoken_languages,
    'status' : status,
    'tagline' : tagline,
    'vote_average' : vote_average,
    'vote_count' : vote_count
})
movies_df.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 2, 'character': 'Dr. Louise Banks...
# 1  [{'cast_id': 3, 'character': 'Troy Maxson', 'c...
# 2  [{'cast_id': 3, 'character': 'Desmond T. Doss'...
# 3  [{'cast_id': 3, 'character': 'Marcus Hamilton'...
# 4  [{'cast_id': 1, 'character': 'Katherine G. Joh...
#
#                                                 crew    budget  \
# 0  [{'credit_id': '55219ea292514170960018df', 'de...  47000000
# 1  [{'credit_id': '57150d48925141387d006150', 'de...  24000000
# 2  [{'credit_id': '5925ff7b9251413ba001460f', 'de...  40000000
# 3  [{'credit_id': '5547ee489251415605000103', 'de...  12000000
# 4  [{'credit_id': '56b40025c3a36806ec0035f0', 'de...  25000000
#
#              genres  movie_id  \
# 0   [18, 878, 9648]    329865
# 1              [18]    393457
# 2   [18, 36, 10752]    324786
# 3  [80, 18, 53, 37]    338766
# 4          [18, 36]    381284
#
#                                             keywords original_language  \
# 0  [{'id': 1612, 'name': 'spacecraft'}, {'id': 59...                en
# 1  [{'id': 1480, 'name': 'baseball'}, {'id': 1543...                en
# 2  [{'id': 233, 'name': 'japan'}, {'id': 1956, 'n...                en
# 3  [{'id': 1333, 'name': 'desperation'}, {'id': 2...                en
# 4  [{'id': 1432, 'name': 'nasa'}, {'id': 4411, 'n...                en
#
#        original_title                                           overview  \
# 0             Arrival  Taking place after alien crafts land around th...
# 1              Fences  In 1950s Pittsburgh, a frustrated African-Amer...
# 2       Hacksaw Ridge  WWII American Army Medic Desmond T. Doss, who ...
# 3  Hell or High Water  A divorced dad and his ex-con brother resort t...
# 4      Hidden Figures  The untold story of Katherine G. Johnson, Doro...
#
#    popularity     ...                                   production_countries  \
# 0      22.192     ...      [{'iso_3166_1': 'US', 'name': 'United States o...
# 1      11.129     ...      [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# 2      20.753     ...      [{'iso_3166_1': 'AU', 'name': 'Australia'}, {'...
# 3      14.927     ...      [{'iso_3166_1': 'US', 'name': 'United States o...
# 4      18.626     ...      [{'iso_3166_1': 'US', 'name': 'United States o...
#
#   release_date    revenue  runtime  \
# 0   2016-11-10  203388186      116
# 1   2016-12-16   64414761      139
# 2   2016-10-07  175302354      139
# 3   2016-08-12   37589296      102
# 4   2016-12-10  230698791      127
#
#                                     spoken_languages    status  \
# 0  [{'iso_639_1': 'zh', 'name': '普通话'}, {'iso_639...  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2  [{'iso_639_1': 'ja', 'name': '日本語'}, {'iso_639...  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline               title  \
# 0                                 Why are they here?             Arrival
# 1  Some people build fences to keep people out, a...              Fences
# 2  One of the greatest heroes in American history...       Hacksaw Ridge
# 3                        Blood always follows money.  Hell or High Water
# 4  Meet the women you don't know, behind the miss...      Hidden Figures
#
#   vote_average  vote_count
# 0          7.4       10588
# 1          6.8        1506
# 2          8.1        6784
# 3          7.3        2508
# 4          8.0        4859
#
# [5 rows x 21 columns]

# %%
#movies_df.to_csv('2018_best_picture_tmdb.csv', index=False)
movies_df.to_csv('2016_2017_best_picture_tmdb.csv', index=False)
