# %%
import pandas as pd
import requests
import json
from sqlalchemy import create_engine
from tmdb_config import API_KEY
from pprint import pprint

# Import csv file
#movie_data = pd.read_csv("bestPic2018Data.csv")
movie_data = pd.read_csv("bestPic2016-2019Data.csv")

movie_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-159be42f122c> in <module>
#       8 # Import csv file
#       9 #movie_data = pd.read_csv("bestPic2018Data.csv")
# ---> 10 movie_data = pd.read_csv("bestPic2016-2019Data.csv")
#      11
#      12 movie_data
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'bestPic2016-2019Data.csv' does not exist

# %%
#list of movie titles to query
movies = movie_data['movieName']
#movies

# %%
# Build the endpoint URL
url = 'https://api.themoviedb.org/3/search/movie?'
api_key = f'api_key={API_KEY}&query='

# set up lists to hold response data:
movie_id = []
genres = []
original_language = []
original_title = []
overview = []
popularity = []
title = []
vote_average = []
vote_count = []

# junk list
junk_list = []

# loop through movie titles, make requests and parse
for movie in movies :
    response = requests.get(url + api_key + movie).json()
    try:
        movie_id.append(response['results'][0]['id'])
        genres.append(response['results'][0]['genre_ids'])
        original_language.append(response['results'][0]['original_language'])
        original_title.append(response['results'][0]['original_title'])
        overview.append(response['results'][0]['overview'])
        popularity.append(response['results'][0]['popularity'])
        title.append(response['results'][0]['title'])
        vote_average.append(response['results'][0]['vote_average'])
        vote_count.append(response['results'][0]['vote_count'])

    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#print(junk_list)
import ast
from pandas.io.json import json_normalize 
url = 'https://api.themoviedb.org/3/genre/movie/list?'
api_key = f'api_key={API_KEY}&language=en-US'
#genres_mapping = []
response = requests.get(url + api_key  ).json()
data = response
df = json_normalize(data, 'genres')
#data.set_index('Locality', inplace=True)
df = df.set_index('id')
#print (df)
# 
# json_str = json.dumps(data)
# data = json.loads(json_str)
# print((data))
print(genres)
genres_cleaned = []
for genre in genres:
    #print(genre)
    genre_name = []
    for i in genre:
        genre_new = {}
        genre_new["id"] = i
        #genre_name.append()
        genre_new["name"] = df.loc[i,'name']
        genre_name.append(genre_new)
    #genre_new = dict(zip("id":genre, "name":genre_name))
    genres_cleaned.append(genre_name)
# print(genres_cleaned)
#(genres_cleaned).replace("'", '"')
print(genres_cleaned)
#genres_data = json.dumps(ast.literal_eval(genres_cleaned))
# genres_clean = json.dumps(genres_cleaned)
# print(genres_clean)
    #[{"id": 28, "name": "Action"}, {"id": 12, "nam.
# Out:
# [[18, 878, 9648], [18], [18, 36, 10752], [80, 18, 53, 37], [18, 36], [35, 18, 10749], [18], [18], [18], [10749, 18], [18, 36], [10752, 28, 18], [9648, 53, 27], [35, 18], [18, 10749], [18, 36], [18, 14, 10749], [80, 18]]
# [[{'id': 18, 'name': 'Drama'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 9648, 'name': 'Mystery'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 10752, 'name': 'War'}], [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}, {'id': 37, 'name': 'Western'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}], [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}], [{'id': 10752, 'name': 'War'}, {'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}], [{'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}], [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}], [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10749, 'name': 'Romance'}], [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]]

# %%
# Making a pass to get more detailed data, have to use ids

# Build the endpoint URL
url = 'https://api.themoviedb.org/3/year/'
api_key = f'?api_key={API_KEY}&query='

budget = []
production_companies = []
production_countries = []
status = []
tagline = []
release_date = []
revenue = []
runtime = []
spoken_languages = []

# loop through movie ids, make requests and parse
for movie in movie_id :
    response = requests.get(url + str(movie) + api_key).json()
    try:
        budget.append(response['budget'])
        production_companies.append(response['production_companies'])
        production_countries.append(response['production_countries'])
        status.append(response['status'])
        tagline.append(response['tagline'])
        release_date.append(response['release_date'])        
        revenue.append(response['revenue'])
        runtime.append(response['runtime'])
        spoken_languages.append(response['spoken_languages'])
    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#budget

# %%
# Making a pass to get cast data, have to use ids

# Build the endpoint URL
url = 'https://api.themoviedb.org/3/movie/'
api_key = f'/credits?api_key={API_KEY}&query='

cast = []
crew = []

# loop through movie ids, make requests and parse
for movie in movie_id :
    response = requests.get(url + str(movie) + api_key).json()
    try:
        cast.append(response['cast'])
        crew.append(response['crew'])
    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#cast

# %%
# Making a pass to get keywords data, have to use ids

# Build the endpoint URL
url = 'https://api.themoviedb.org/3/movie/'
api_key = f'/keywords?api_key={API_KEY}&query='

keywords = []

# loop through movie ids, make requests and parse
for movie in movie_id :
    response = requests.get(url + str(movie) + api_key).json()
    try:
        keywords.append(response['keywords'])
    except:
        #print(movie, response)
        junk_list.append(movie)

# %%
#keywords

# %%
# This Block for sorting through errors
print(genres_cleaned)
#print("Length of Ranks Series: " , len(ranks))
#for junk in junk_list:
#    print(junk)
#    i=movies[movies==junk]
#    print(i.index, i.index[0])
#    ranks = ranks.drop(i.index[0])
#print("Length of Ranks Series: " , len(ranks))
# Out:
# [[{'id': 18, 'name': 'Drama'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 9648, 'name': 'Mystery'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 10752, 'name': 'War'}], [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}, {'id': 37, 'name': 'Western'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}], [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}], [{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}], [{'id': 10752, 'name': 'War'}, {'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}], [{'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}], [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}], [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}], [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}], [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10749, 'name': 'Romance'}], [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]]

# %%
# save data to pandas dataframe
movies_df = pd.DataFrame({
    'title' : title,
    'cast' : cast,
    'crew' : crew,
    'budget' : budget,
    'genres_new' : genres_cleaned,
    'movie_id' : movie_id,
    'keywords' : keywords,
    'original_language' : original_language,
    'original_title' : original_title,
    'overview' : overview,
    'popularity' : popularity,
    'production_companies' : production_companies,
    'production_countries' : production_countries,
    'release_date' : release_date,
    'revenue' : revenue,
    'runtime' : runtime,
    'spoken_languages' : spoken_languages,
    'status' : status,
    'tagline' : tagline,
    'vote_average' : vote_average,
    'vote_count' : vote_count
})
movies_df.tail()
# movies_df.genres
# Out:
#                                         title  \
# 13                                  Lady Bird
# 14                             Phantom Thread
# 15                                   The Post
# 16                         The Shape of Water
# 17  Three Billboards Outside Ebbing, Missouri
#
#                                                  cast  \
# 13  [{'cast_id': 2, 'character': 'Christine "Lady ...
# 14  [{'cast_id': 2, 'character': 'Reynolds Woodcoc...
# 15  [{'cast_id': 1, 'character': 'Kay Graham', 'cr...
# 16  [{'cast_id': 13, 'character': 'Elisa Esposito'...
# 17  [{'cast_id': 0, 'character': 'Mildred Hayes', ...
#
#                                                  crew    budget  \
# 13  [{'credit_id': '5705b7a2c3a3685d4c0008c7', 'de...  10000000
# 14  [{'credit_id': '57516e2cc3a3686bec0008d4', 'de...  35000000
# 15  [{'credit_id': '58c4313ac3a36853360000ff', 'de...  50000000
# 16  [{'credit_id': '57cbabe2c3a3686744005cd2', 'de...  19500000
# 17  [{'credit_id': '55f7440cc3a3686d0300b7a9', 'de...  15000000
#
#                                            genres_new  movie_id  \
# 13  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    391713
# 14  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...    400617
# 15  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...    446354
# 16  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...    399055
# 17  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...    359940
#
#                                              keywords original_language  \
# 13  [{'id': 10683, 'name': 'coming of age'}, {'id'...                en
# 14  [{'id': 212, 'name': 'london'}, {'id': 1157, '...                en
# 15  [{'id': 521, 'name': 'washington d.c.'}, {'id'...                en
# 16  [{'id': 2106, 'name': 'cold war'}, {'id': 2672...                en
# 17  [{'id': 236, 'name': 'suicide'}, {'id': 570, '...                en
#
#                                original_title  \
# 13                                  Lady Bird
# 14                             Phantom Thread
# 15                                   The Post
# 16                         The Shape of Water
# 17  Three Billboards Outside Ebbing, Missouri
#
#                                              overview  ...  \
# 13  A California high school student plans to esca...  ...
# 14  Renowned British dressmaker Reynolds Woodcock ...  ...
# 15  A cover-up that spanned four U.S. Presidents p...  ...
# 16  An other-worldly story, set against the backdr...  ...
# 17  After seven months have passed without a culpr...  ...
#
#                                  production_companies  \
# 13  [{'id': 93105, 'logo_path': None, 'name': 'IAC...
# 14  [{'id': 178, 'logo_path': None, 'name': 'Ghoul...
# 15  [{'id': 56, 'logo_path': '/cEaxANEisCqeEoRvODv...
# 16  [{'id': 101082, 'logo_path': None, 'name': 'Do...
# 17  [{'id': 2376, 'logo_path': '/yeNoWmSHZfvKsBYuL...
#
#                                  production_countries release_date    revenue  \
# 13  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-09-08   76858273
# 14  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-12-25   47756590
# 15  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-12-22  174503458
# 16  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-12-01  194989655
# 17  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2017-11-10  158526998
#
#     runtime                                   spoken_languages    status  \
# 13       94           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14      130  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 15      116           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 16      123  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 17      115           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                             tagline vote_average  vote_count
# 13                   Fly Away Home.          7.3        3989
# 14                                           7.3        1663
# 15                    Truth be told          7.0        2566
# 16  A Fairy Tale for Troubled Times          7.2        7418
# 17                                           8.2        5577
#
# [5 rows x 21 columns]

# %%
#movies_df.to_csv('2018_best_picture_tmdb.csv', index=False)
#movies_df.to_csv('2016_2017_best_picture_tmdb2.csv', index=False)
movies_df.to_csv('2019_best_picture_tmdb.csv', index=False)
