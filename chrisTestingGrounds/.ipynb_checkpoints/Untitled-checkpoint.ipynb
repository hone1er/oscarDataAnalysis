# %%
import pandas as pd
import os

# %%
df = pd.read_csv("bestPictureMasterList.csv")
df.head(2)
# Out:
#    winner         movie_title  \
# 0     1.0  lawrence of arabia
# 1     1.0     the longest day
#
#                                                 cast  \
# 0  [{"cast_id": 18, "character": "T.E. Lawrence",...
# 1  [{"cast_id": 20, "character": "Col. Thompson",...
#
#                                                 crew    budget  \
# 0  [{"credit_id": "5715157dc3a3684122010c0c", "de...  15000000
# 1  [{"credit_id": "53ba7918c3a3685eb1006f7a", "de...  10000000
#
#                                               genres  \
# 0  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 1  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
#
#                                             keywords original_language  \
# 0  [{"id": 487, "name": "cairo"}, {"id": 1975, "n...                en
# 1  [{"id": 1956, "name": "world war ii"}, {"id": ...                en
#
#        original_title                                           overview  ...  \
# ...

# %%
#Adding a column to the original that will hold the Bechdel bool, init as 0 (False)
#! I don't think this will work as changing a value mid itterow is troublesome
#df['Bechdel_Test'] = 0
#df.head(2)

# %%
import requests, json

byTitle_baseURL = "http://bechdeltest.com/api/v1/getMoviesByTitle?title="

# Function to call the Bechdel Test API with a movie title
def callAPI(searchTitle):
    print(f"Calling API with movie title: '{searchTitle}'\n")
    conn = str(requests.get(byTitle_baseURL + searchTitle).json())
    #conn = str(conn)
    #conn = conn.split()
    #conn = str(conn)
    #print(conn, "\n")
    #print(len(conn), "\n")
    if len(conn) <= 2:
        #print(f"[!] Failure")
        return 0
    else:
        #print("Success")
        return 1

# %%
import time


bechdel_verdicts = []

# Iterate each DF row and check the bechdel test API for a score && change bool to 1 (True)
for row in df.iterrows():
    
    print("On call " + str(len(bechdel_verdicts) + 1) + "/" + "4795")
    
    # Rate limit our calls as to not be rude
    time.sleep(.90)
    
    # Stick the current row's movie_title value into a temp var for ease of use
    searchTitle = str(row[1].movie_title)
    
    # Call API with the movie_title as the parameter
    verdict = callAPI(searchTitle)
    #print(verdict, "\n")
    
    bechdel_verdicts.append(verdict)
# Out:
# On call 1/4795
# Calling API with movie title: 'lawrence of arabia'
#
# On call 2/4795
# Calling API with movie title: 'the longest day'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-243464bc6e27> in <module>
#      16
#      17     # Call API with the movie_title as the parameter
# ...

# %%
print(bechdel_verdicts)
df['Bechdel_Test'] = bechdel_verdicts
df.head(5)
