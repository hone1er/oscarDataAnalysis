# %% [markdown]
# # WELCOME TO THE OSCAR DATA ANALYSIS

# %%
import pandas as pd
import os

# %%
file = os.path.join(os.path.dirname('__file__'), "resources/database.csv")
df = pd.read_csv(file)

# %%
df
# Out:
#            Year  Ceremony                             Award  Winner  \
# 0     1927/1928         1                             Actor     NaN
# 1     1927/1928         1                             Actor     1.0
# 2     1927/1928         1                           Actress     NaN
# 3     1927/1928         1                           Actress     1.0
# 4     1927/1928         1                           Actress     NaN
# 5     1927/1928         1                     Art Direction     NaN
# 6     1927/1928         1                     Art Direction     1.0
# 7     1927/1928         1                     Art Direction     NaN
# 8     1927/1928         1                    Cinematography     NaN
# 9     1927/1928         1                    Cinematography     1.0
# 10    1927/1928         1                    Cinematography     1.0
# 11    1927/1928         1        Directing (Comedy Picture)     1.0
# 12    1927/1928         1        Directing (Comedy Picture)     NaN
# ...

# %%
groupedDF = df.groupby('Year').count()
groupedDF
# Out:
#            Ceremony  Award  Winner  Name  Film
# Year
# 1927/1928        35     35      15    35    31
# 1928/1929        38     38       7    38    38
# 1929/1930        42     42       8    42    42
# 1930/1931        44     44       9    44    40
# 1931/1932        45     45      14    45    41
# 1932/1933        62     62      19    62    44
# 1934             64     64      17    64    63
# 1935             86     86      18    86    85
# 1936            107    107      22   107   106
# 1937            123    123      25   123   120
# 1938            139    139      25   139   128
# 1939            143    143      26   143   138
# 1940            160    160      24   160   158
# 1941            183    183      28   183   181
# 1942            186    186      30   186   184
# 1943            182    182      26   182   180
# 1944            169    169      27   169   165
# 1945            160    160      28   160   156
# 1946            104    104      28   104   101
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
# Out:
# C:\Users\josep\Anaconda3\lib\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
# Using plotly + cufflinks in offline mode

# you might need to pip install cufflinks
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
file = os.path.join(os.path.dirname('__file__'), "resources/tmdb_5000_movies.csv.zip")
df2 = pd.read_csv(file, compression='zip')
df2
#df2 = df2[['original_title', 'title', 'release_date', 'budget', 'revenue', 'popularity', 'vote_average', 'vote_count']]
#df2 = df2[(df2 != 0).all(1)]
#df2.set_index(['original_title', 'title'], inplace=True)
#df2.to_csv('movieGraph.csv', index=True, index_label='original_title')
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
df = pd.read_csv("resources/movieGraph.csv", index_col=['original_title','title'])
df.index.levels[1].unique()
# Out:
# Index(['(500) Days of Summer', '10 Cloverfield Lane',
#        '10 Things I Hate About You', '102 Dalmatians', '10th & Wolf',
#        '12 Angry Men', '12 Rounds', '12 Years a Slave', '127 Hours',
#        '13 Going on 30',
#        ...
#        'Zookeeper', 'Zoolander', 'Zoolander 2', 'Zoom', '[REC]', '[REC]²',
#        'eXistenZ', 'xXx', 'xXx: State of the Union', 'Æon Flux'],
#       dtype='object', name='title', length=3226)

# %%
file = os.path.join(os.path.dirname('__file__'), "resources/tmdb_5000_credits.csv.zip")
df3 = pd.read_csv(file, compression='zip')

# %%
df3
# Out:
#       movie_id                                        title  \
# 0        19995                                       Avatar
# 1          285     Pirates of the Caribbean: At World's End
# 2       206647                                      Spectre
# 3        49026                        The Dark Knight Rises
# 4        49529                                  John Carter
# 5          559                                 Spider-Man 3
# 6        38757                                      Tangled
# 7        99861                      Avengers: Age of Ultron
# 8          767       Harry Potter and the Half-Blood Prince
# 9       209112           Batman v Superman: Dawn of Justice
# 10        1452                             Superman Returns
# 11       10764                            Quantum of Solace
# 12          58   Pirates of the Caribbean: Dead Man's Chest
# 13       57201                              The Lone Ranger
# 14       49521                                 Man of Steel
# ...

# %%
import requests
import json

def get_page_data(page_id,access_token):
    api_endpoint = "https://graph.facebook.com/v2.4/"
    fb_graph_url = api_endpoint+page_id+"?fields=id,name,likes,link&access_token="+access_token
    try:
        api_response = requests.get(fb_graph_url)
        print(api_response.json())
        try:
            return api_response.json()
        except (ValueError, KeyError, TypeError):
            return "JSON error"

    except IOError as e:
        if hasattr(e, 'code'):
            return e.code
        elif hasattr(e, 'reason'):
            return e.reason

page_id = "idiotinside" # username or id
token = '1459590670849365|xrTO82QRyZqkkfz2ghAtrYDmppY'  # Access Token
page_data = get_page_data(page_id,token)

print(page_data)
# Out:
# {'error': {'message': "(#10) To use 'Page Public Content Access', your use of this endpoint must be reviewed and approved by Facebook. To submit this 'Page Public Content Access' feature for review please read our documentation on reviewable features: https://developers.facebook.com/docs/apps/review.", 'type': 'OAuthException', 'code': 10, 'fbtrace_id': 'A4wHwJhiJiE1pGUxb2JXwyG'}}
# {'error': {'message': "(#10) To use 'Page Public Content Access', your use of this endpoint must be reviewed and approved by Facebook. To submit this 'Page Public Content Access' feature for review please read our documentation on reviewable features: https://developers.facebook.com/docs/apps/review.", 'type': 'OAuthException', 'code': 10, 'fbtrace_id': 'A4wHwJhiJiE1pGUxb2JXwyG'}}

# %%
import requests

def get_fb_token(app_id, app_secret):
    url = 'https://graph.facebook.com/oauth/access_token'       
    payload = {
        'grant_type': 'client_credentials',
        'client_id': app_id,
        'client_secret': app_secret
    }
    response = requests.post(url, params=payload)
    return response.json()['access_token']
